# %% [markdown]
# No need to run all

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import auth
auth.authenticate_user()
print('Authenticated')
# Out:
# Authenticated

# %%
# exclude all cancelled orders
# only keep the US orders
# exclude all refunded orders ## update on 06/24/2024: keep all refunded orders
# exclude all shopify draft orders
# only keep the non-wholesale orders
# ## update on 07/02/2024: exclude all meta orders
# exclude all empty email orders
# only keep the orders with sku
# exclude all zero pre_tax_price products
# exclude all zero netproducts
# save output in a variable `df`
## 2023-2024 Data

# %%bigquery df --project fb-business-ws
SELECT order_number, created_at, shipping_address_province_code, email, source_channel, sku, title, quantity, revenue, net
FROM fb-business-ws.enriched_marketing.shopify_orderlines
WHERE EXTRACT(year from processed_at) IN (2023,2024) AND cancelled_at IS NULL AND shipping_address_country_code = 'US' AND
source_name != 'shopify_draft_order' AND wholesale_tag IS NULL AND meta_tag is NULL AND email != '' AND sku is not null AND pre_tax_price > 0 AND net > 0
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |

# %%
############ FUNCTION #############

def max_interval(series):
  if series.isnull().any():
    return pd.NA
  else:
    return series.max()

def clean_orderlines(df):
  """
    Combine non-US province code into 'Other';
    calculate purchasing intervals;
    combine 'source_channel' into several main categories

    Parameters:
    df: The dataframe retrived from BigQuery.

    Returns:
    df: The preprocessed datafrme.
    """

  ## drop duplications
  df = df.drop_duplicates()

  ## combine non-US province code into 'Other'
  USstates = ['AL','AK','AZ','AR','AS','AE','AP','AA','CA','CO','CT','DE','DC','FL','GA','GU','HI','ID','IL','IN','IA','KS','KY','LA',
              'ME','MD','MA','MI','MN','MS','MO','MT','MP','NE','NV','NH','NJ','NM','NY','NC','ND','OH','OK',
              'OR','PA','PR','RI','SC','SD','TN','TX','UT','UM','VT','VI','VA','WA','WV','WI','WY']
  df.loc[~df['shipping_address_province_code'].isin(USstates), 'shipping_address_province_code'] = 'Other'

  ## calculate purchasing intervals (number of days between two orders made with the same customer email)
  # sort the dataset by 'email' and 'created_at' to ensure consecutive purchases for each customer
  df = df.sort_values(by=['email', 'created_at'])
  # calculate the interval between consecutive purchases for each customer
  df['interval'] = df.groupby('email')['created_at'].diff().dt.days
  # for rows where 'email' changes, reset the interval to NaN to indicate a new customer
  df['interval'] = df['interval'].where(df['email'].eq(df['email'].shift()))
  # create a dictionary to map 'order_number' to the interval value
  order_id_interval_map = df.groupby('order_number')['interval'].agg(max_interval).to_dict()
  # map the interval value back to each row based on 'order_number'
  df['interval'] = df['order_number'].map(order_id_interval_map)

  ## combine 'source_channel' into several main categories
  df.loc[pd.isnull(df['source_channel']), 'source_channel'] = 'Unkown'
  df.loc[df['source_channel'] == '', 'source_channel'] = 'Unkown'
  # Define mappings of patterns to replacement values
  mapping = {
    'fb|facebook|meta|facbook|facebad': 'Facebook(PS)',
    'ig|instagram': 'Instagram(Other)',
    'bing': 'Bing(PSH)',
    'klaviyo': 'Klaviyo(E)',
    'attentive': 'Attentive(T)',
    # main channels
    'paid|pinterest|youtube|tiktok': 'Paid Social',
    'dailycampaign|text|flow': 'Text',
    'orderlyemail|yotpo|mail|newsletter': 'Email',
    'hoobe|organic|navigation|linkinbio': 'Organic & Social',
    'google|microsoft': 'Paid Search',
    'homepage': 'Display',
    'affluencer|affiliate': 'Affiliate',
    'BeefeylFzbvyf|bethany|ciolota|chris|chrome|google_shopping|klarna|loyalty|narrativ|octoly|refer|shop_app|thingtesting.com|trustpilot|color wow|direct|excluded|tbbtyf|non-attributed|baavyvbgf': 'Other'
  }

  # Use regex to match patterns and replace values in 'main_channel' column
  for pattern, replacement in mapping.items():
    df.loc[df['source_channel'].str.contains(pattern, case=False), 'source_channel'] = replacement
  df.loc[df['source_channel'] == 'social', 'source_channel'] = 'Organic & Social'
  category = ['Unkown','Facebook(PS)','Instagram(Other)','Bing(PSH)','Klaviyo(E)','Attentive(T)','Paid Social','Text','Email','Organic & Social','Paid Search','Display','Affiliate']
  df.loc[~df['source_channel'].isin(category), 'source_channel'] = 'Other'

  ## Resetting the index of the cleaned dataset
  df.reset_index(drop=True, inplace=True)

  return df

# %%
df = clean_orderlines(df)
print(df.shape[0])
# Out:
# 1460502

# %%
project_id = 'fb-business-datasets'  # Google Cloud project ID
destination_table = 'fb-business-datasets.ds_tables.cleaned_shopify_orderlines_newest'  # destination table name in BigQuery
df.to_gbq(destination_table, project_id=project_id, if_exists='replace')
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 630.44it/s]

# %% [markdown]
# Function Development

# %%
# exclude all cancelled orders
# only keep the US orders
# exclude all refunded orders  ## update on 6/24; keep all refunded orders
# exclude all shopify draft orders
# only keep the non-wholesale orders
# exclude all empty email orders
# only keep the orders with sku
# exclude all zero pre_tax_price products
# exclude all zero netproducts
# save output in a variable `df`
## 2023 Data Only

# %%bigquery df --project fb-business-ws
SELECT order_number, created_at, shipping_address_province_code, email, source_channel, sku, title, quantity, revenue, net
FROM fb-business-ws.enriched_marketing.shopify_orderlines
WHERE EXTRACT(year from processed_at) = 2023 AND cancelled_at IS NULL AND shipping_address_country_code = 'US' AND source_name != 'shopify_draft_order' AND email != '' AND wholesale_tag is null AND sku is not null AND pre_tax_price > 0 AND net > 0
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |

# %%
df.head()
# Out:
#    order_number                created_at shipping_address_province_code  \
# 0       1486930 2023-05-18 05:56:10+00:00                             TX
# 1       1381635 2023-02-27 03:43:50+00:00                             GA
# 2       1445294 2023-04-13 00:35:22+00:00                             CA
# 3       1669240 2023-08-31 06:11:12+00:00                             TX
# 4       1374640 2023-02-21 06:41:31+00:00                             CA
#
#                       email source_channel    sku          title  quantity  \
# 0  irmahinojosa95@gmail.com         klarna  CW419       Easy Blo         1
# 1         maso916@yahoo.com           None  CW419       Easy Blo         1
# 2      shradha.k9@gmail.com           None  CW419       Easy Blo         1
# 3   cindytejeda@verizon.net  daily-klaviyo  CW419       Easy Blo         1
# 4    shannonnew10@gmail.com           None  CW415  Thats a Wrap!         1
#
#    revenue   net
# 0     49.0  49.0
# 1     49.0  49.0
# 2     49.0  49.0
# 3     49.0  49.0
# 4     22.0  22.0

# %% [markdown]
# #### Preprocessing Dataset
# 1. drop duplications
# 2. `shipping_address_province_code`: if not US states than 'Other'
# 3. `interval`: create such a column to calculate the purchase interval
# 4. `source_channel`: keep the main channels
# 5. check if other columns containing null values or not
# 6. check data types and convert into wanted data types

# %%
df.shape
# Out:
# (1643327, 10)

# %%
df = df.drop_duplicates()
df.shape
# Out:
# (1643278, 10)

# %%
df.isna().sum()
# Out:
# order_number                           0
# created_at                             0
# shipping_address_province_code         0
# email                                  0
# source_channel                    684632
# sku                                    0
# title                                  0
# quantity                               0
# revenue                                0
# net                                    0
# dtype: int64

# %%
## combine non-US province code into 'Other'
USstates = ['AL','AK','AZ','AR','AS','AE','AP','AA','CA','CO','CT','DE','DC','FL','GA','GU','HI','ID','IL','IN','IA','KS','KY','LA',
            'ME','MD','MA','MI','MN','MS','MO','MT','MP','NE','NV','NH','NJ','NM','NY','NC','ND','OH','OK',
            'OR','PA','PR','RI','SC','SD','TN','TX','UT','UM','VT','VI','VA','WA','WV','WI','WY']

df.loc[~df['shipping_address_province_code'].isin(USstates), 'shipping_address_province_code'] = 'Other'
print(df['shipping_address_province_code'].nunique())
print(df['shipping_address_province_code'].unique())
# Out:
# 58
# ['FL' 'NY' 'PA' 'MO' 'DE' 'CO' 'TX' 'CA' 'NE' 'VA' 'NC' 'MN' 'MA' 'OH'
#  'IN' 'KY' 'NJ' 'AL' 'WA' 'WI' 'OK' 'WY' 'GA' 'WV' 'TN' 'IL' 'AZ' 'ID'
#  'UT' 'HI' 'MI' 'LA' 'NH' 'MS' 'ME' 'SC' 'RI' 'AR' 'KS' 'NV' 'CT' 'MD'
#  'IA' 'NM' 'OR' 'MT' 'DC' 'SD' 'ND' 'AK' 'PR' 'VT' 'AE' 'GU' 'VI' 'AA'
#  'AP' 'MP']

# %%
df['created_at'].min()
# Out:
# Timestamp('2023-01-01 00:01:31+0000', tz='UTC')

# %%
## calculate purchasing intervals (number of days between two orders made with the same customer email)

# sort the dataset by 'email' and 'created_at' to ensure consecutive purchases for each customer
df = df.sort_values(by=['email', 'created_at'])
# calculate the interval between consecutive purchases for each customer
df['interval'] = df.groupby('email')['created_at'].diff().dt.days
# for rows where 'email' changes, reset the interval to NaN to indicate a new customer
df['interval'] = df['interval'].where(df['email'].eq(df['email'].shift()))
# Create a dictionary to map 'order_number' to the interval value
def max_interval(series):
    if series.isnull().any():
        return pd.NA
    else:
        return series.max()
order_id_interval_map = df.groupby('order_number')['interval'].agg(max_interval).to_dict()
# Map the interval value back to each row based on 'order_number'
df['interval'] = df['order_number'].map(order_id_interval_map)

# %%
df.head(5)
# Out:
#         order_number                created_at shipping_address_province_code  \
# 658576       1618165 2023-08-09 20:05:18+00:00                             MA
# 281130       1447811 2023-04-15 17:21:29+00:00                             FL
# 613259       1447811 2023-04-15 17:21:29+00:00                             FL
# 101295       1852531 2023-12-18 22:42:37+00:00                             TX
# 552217       1852531 2023-12-18 22:42:37+00:00                             TX
#
#                               email source_channel     sku  \
# 658576    +1508596smbak55@gmail.com           None   CW548
# 281130   0-orange-braces@icloud.com  daily-klaviyo   CW510
# 613259   0-orange-braces@icloud.com  daily-klaviyo   CW528
# 101295  0.aliases.iambic@icloud.com       facebook   CW528
# 552217  0.aliases.iambic@icloud.com       facebook  CWB103
#
#                                                     title  quantity  revenue  \
# 658576             Dream Filter For Picture-Perfect Color         1     24.0
# 281130                             Color Security Shampoo         1     24.0
# 613259   Style on Steroids ~ Color-Safe Texturizing Spray         1     26.0
# 101295   Style on Steroids ~ Color-Safe Texturizing Spray         1     26.0
# 552217  Extra Mist-ical Shine Spray + FREE* Puffer Bag...         1     29.0
#
#          net  interval
# 658576  24.0       NaN
# 281130  24.0       NaN
# 613259  26.0       NaN
# 101295  26.0       NaN
# 552217  29.0       NaN

# %%
## clean the source_channel
print(df['source_channel'].nunique())
print(df['source_channel'].unique())
print(df['source_channel'].value_counts(normalize=True) * 100)
# Out:
# 224
# [None 'daily-klaviyo' 'facebook' 'flow-klaviyo' 'flow-text'
#  'dailycampaign-text-' 'dailycampaign-text  ' 'pinterest' 'hoobe'
#  'affiliate' 'homepage' 'attentive' 'Facebook' 'tiktok' 'bing'
#  'flow-text  ' 'OrderlyEmails' 'Klaviyo' 'yotpo' 'dailycampaign-text'
#  'klarna' 'fb' 'navigation' 'Pinterest' 'IGShopping' 'shop_app' ''
#  'listrak' 'loyalty' 'paid' 'fbn' 'google' 'dailycampaign-text '
#  'PaidSocial' 'youtube' 'SMSBump'
#  'dailycampaign-text  utm_source=dailycampaign-text  '
#  'Malomo Post Purchase: 4. Delivered' 'Facebook_Mobile_Feed' 'ig'
#  'Meta-SiteLink-644-2' 'drip' 'Google' 'Meta-SiteLink-1126-0'
#  'B TRACK—Lightly Engaged (30-60 days)' 'Meta-SiteLink-3427-2' 'sfmc'
#  'Iterable' 'active_campaign' 'Meta-SiteLink-644-1' 'email'
#  'Meta-SiteLink-1133-0' 'fbig' 'CTC FB' 'organic' 'powereditor'
#  'linkinbio' 'Meta-SiteLink-190-0' 'USPatriotFlags by Ultimate Flags LLCb'
#  'preflect' 'Proozy' 'Digestive Support Protein Customers'
#  'MMP-SiteLink-189-0' '6259466001825' 'Meta-SiteLink-188-0' 'Impact'
#  'L | Abandoned Checkout' 'social' 'facebook-SiteLink-188-0' 'facebook-fb'
#  'Meta-SiteLink-644-0' 'Abandoned Cart - NEW YEARS SALE 2023'
#  'facebook-SiteLink-680-0' 'ReSci' 'FB' 'TikTok' 'postscript'
#  'active on site last two days' 'Email' 'Meta-SiteLink-1127-0'
#  'daily klaviyo' 'Brand Enthusiasts' 'facebookads' '23854884683410564'
#  'facebook_instagram' 'flow' 'omnisend' 'current' 'Meta-SiteLink-190-1'
#  'facebook_prospecting' 'FacebookADS'
#  'FX - Retention Full Engagement - 60 ' '360SWEATER HQ' 'Newsletter' 'GO'
#  'refersion' 'Lemonade Electrolytes (Tub)' 'junip' '30 days engage'
#  'facebook-SiteLink-688-1' 'facebook.com' 'chirp' 'broadcast'
#  'Instagram_Stories' 'facebook-SiteLink-683-0' 'facebook-instagram'
#  'Instagram_Stories ' 'avantlink' 'facebook-ig' 'Chris' '6290122498225'
#  'criteo' 'Bees Wrap Master List' 'YourSoberPal' 'Facebook_Ads fb'
#  'EMAIL CAMPAIGNS' 'khangfujobi2newvid' 'MC | VIP' 'klaviyo'
#  'Meta-SiteLink-179-0' 'zaius' 'Jenni Kayne Newsletter' 'paid.social'
#  'pepperjam' 'Instagram' 'Samples Push - Engaged, No Purchase'
#  'facebook-SiteLink-190-1' 'ALL Past Purchasers - 1X' 'wunderkind'
#  'linkshare' 'PAID' 'Meta-SiteLink-644-7' 'Meta-SiteLink-3427-1'
#  'Meta-SiteLink-1133-5' 'twitter' 'leaddyno' 'Meta' 'Meta-SiteLink-1133-1'
#  'Meta-SiteLink-1133-2' 'smile_rewards' 'narrativ' '6261289086425'
#  'Meta-SiteLink-179-2' 'Meta-SiteLink-644-5' 'NM - JC - Waiting for Wows'
#  'SMS' 'Active Customers   Active on site addition'
#  '01 | Wonderment | Shipping | Shipment Created' 'NP   Active On Site'
#  'seguno' 'Q4 - First Touch' 'paid_social'
#  'HappyWax - Master list Segment' '3829940' 'Meta-SiteLink-179-1'
#  'campaign' 'Bar Buyers' 'Campaigns: Smaller Send'
#  'Growth Gurus | Omnilux LED | Engaged Contacts 365 Days'
#  'facebook-SiteLink-683-2' 'bluecore' 'Meta-SiteLink-1127-1'
#  'shopify_email' 'XML' 'SMSBump Subscribers original' 'influencer'
#  'instagram' 'Recent Newsletter Subscribers - 45 Days'
#  'Bagnet SMS Subscribers - Consented for SMS' 'cordial' 'meta'
#  'Meta-SiteLink-190-5' 'HS // Engaged 120D - Other' 'Black Friday List'
#  'braze' 'Meta-SiteLink-3427-3' 'facebook-SiteLink-688-2'
#  'KLAV - 30d Engaged - BOTH or EMPTY Preference' 'All ESI Subscribers'
#  'Meta-SiteLink-189-1' 'Newsletter Signup' 'Organic' 'All Engaged 45 Day'
#  'Meta-SiteLink-188-2' "[SW] Women's 30 Day Engaged - SMS" 'fbasc'
#  'SMS Engaged 30 days, bought 365' 'makarov_fb'
#  'Retention: Engaged (Send To)' 'GOOGLE' 'Subscribed All**'
#  'Beadaholique Insider' 'Meta-SiteLink-188-1' 'Warm 150 Days' 'facebad'
#  'Meta-SiteLink-644-4' 'ShopMy' 'Active Customers   Active on Site'
#  'Welcome Series ESI 3.0' 'SM l 30 Day Engaged' 'ssw' 'newsletter (all)'
#  'pj' 'abandoned_cart' 'native-app'
#  'TPC Email Subscribers - Engage 90 Days' 'Paid' 'Klaviyoflow'
#  'facebook-SiteLink-683-4' 'fb_ig' '24 months engaged segment' 'snappic'
#  'Growth Gurus | Omnilux LED | Engaged Contacts 90 Days'
#  'Growth Gurus | Omnilux LED | Engaged Contacts 120 Days' 'hs_email'
#  'Engaged 3 Months (Exclude MPP Openers)' 'Website Opt In'
#  'thingtesting.com'
#  '[EG]  Subscribers  |  Engaged  |  Customers  |  Subscription  |  Active  (Loose - 150 Day Opens)'
#  'Opened/Clicked/Purchased 500 Days'
#  'CP Loyalty Master List_ALL SUBSCRIBERS _180 Engaged 81121' 'catch'
#  'All B2C Subscribers' 'paidsocial' 'tiktokad']
# source_channel
# facebook                          45.090576
# daily-klaviyo                     20.521965
# dailycampaign-text                 6.493951
# flow-text                          6.298780
# flow-klaviyo                       4.007423
#                                     ...
# HappyWax - Master list Segment     0.000104
# Q4 - First Touch                   0.000104
# NP   Active On Site                0.000104
# NM - JC - Waiting for Wows         0.000104
# tiktokad                           0.000104
# Name: proportion, Length: 224, dtype: float64

# %%
df.loc[pd.isnull(df['source_channel']), 'source_channel'] = 'Unkown'
df.loc[df['source_channel'] == '', 'source_channel'] = 'Unkown'
print(df['source_channel'].value_counts(normalize=True) * 100)
# Out:
# source_channel
# Unkown                            41.685278
# facebook                          26.304679
# daily-klaviyo                     11.971985
# dailycampaign-text                 3.788403
# flow-text                          3.674546
#                                     ...
# HappyWax - Master list Segment     0.000061
# Q4 - First Touch                   0.000061
# NP   Active On Site                0.000061
# NM - JC - Waiting for Wows         0.000061
# tiktokad                           0.000061
# Name: proportion, Length: 224, dtype: float64

# %%
print(df['source_channel'].sort_values().unique())
# Out:
# ['01 | Wonderment | Shipping | Shipment Created' '23854884683410564'
#  '24 months engaged segment' '30 days engage' '360SWEATER HQ' '3829940'
#  '6259466001825' '6261289086425' '6290122498225'
#  'ALL Past Purchasers - 1X' 'Abandoned Cart - NEW YEARS SALE 2023'
#  'Active Customers   Active on Site'
#  'Active Customers   Active on site addition' 'All B2C Subscribers'
#  'All ESI Subscribers' 'All Engaged 45 Day'
#  'B TRACK—Lightly Engaged (30-60 days)'
#  'Bagnet SMS Subscribers - Consented for SMS' 'Bar Buyers'
#  'Beadaholique Insider' 'Bees Wrap Master List' 'Black Friday List'
#  'Brand Enthusiasts'
#  'CP Loyalty Master List_ALL SUBSCRIBERS _180 Engaged 81121' 'CTC FB'
#  'Campaigns: Smaller Send' 'Chris' 'Digestive Support Protein Customers'
#  'EMAIL CAMPAIGNS' 'Email' 'Engaged 3 Months (Exclude MPP Openers)' 'FB'
#  'FX - Retention Full Engagement - 60 ' 'Facebook' 'FacebookADS'
#  'Facebook_Ads fb' 'Facebook_Mobile_Feed' 'GO' 'GOOGLE' 'Google'
#  'Growth Gurus | Omnilux LED | Engaged Contacts 120 Days'
#  'Growth Gurus | Omnilux LED | Engaged Contacts 365 Days'
#  'Growth Gurus | Omnilux LED | Engaged Contacts 90 Days'
#  'HS // Engaged 120D - Other' 'HappyWax - Master list Segment'
#  'IGShopping' 'Impact' 'Instagram' 'Instagram_Stories'
#  'Instagram_Stories ' 'Iterable' 'Jenni Kayne Newsletter'
#  'KLAV - 30d Engaged - BOTH or EMPTY Preference' 'Klaviyo' 'Klaviyoflow'
#  'L | Abandoned Checkout' 'Lemonade Electrolytes (Tub)' 'MC | VIP'
#  'MMP-SiteLink-189-0' 'Malomo Post Purchase: 4. Delivered' 'Meta'
#  'Meta-SiteLink-1126-0' 'Meta-SiteLink-1127-0' 'Meta-SiteLink-1127-1'
#  'Meta-SiteLink-1133-0' 'Meta-SiteLink-1133-1' 'Meta-SiteLink-1133-2'
#  'Meta-SiteLink-1133-5' 'Meta-SiteLink-179-0' 'Meta-SiteLink-179-1'
#  'Meta-SiteLink-179-2' 'Meta-SiteLink-188-0' 'Meta-SiteLink-188-1'
#  'Meta-SiteLink-188-2' 'Meta-SiteLink-189-1' 'Meta-SiteLink-190-0'
#  'Meta-SiteLink-190-1' 'Meta-SiteLink-190-5' 'Meta-SiteLink-3427-1'
#  'Meta-SiteLink-3427-2' 'Meta-SiteLink-3427-3' 'Meta-SiteLink-644-0'
#  'Meta-SiteLink-644-1' 'Meta-SiteLink-644-2' 'Meta-SiteLink-644-4'
#  'Meta-SiteLink-644-5' 'Meta-SiteLink-644-7' 'NM - JC - Waiting for Wows'
#  'NP   Active On Site' 'Newsletter' 'Newsletter Signup'
#  'Opened/Clicked/Purchased 500 Days' 'OrderlyEmails' 'Organic' 'PAID'
#  'Paid' 'PaidSocial' 'Pinterest' 'Proozy' 'Q4 - First Touch' 'ReSci'
#  'Recent Newsletter Subscribers - 45 Days' 'Retention: Engaged (Send To)'
#  'SM l 30 Day Engaged' 'SMS' 'SMS Engaged 30 days, bought 365' 'SMSBump'
#  'SMSBump Subscribers original' 'Samples Push - Engaged, No Purchase'
#  'ShopMy' 'Subscribed All**' 'TPC Email Subscribers - Engage 90 Days'
#  'TikTok' 'USPatriotFlags by Ultimate Flags LLCb' 'Unkown' 'Warm 150 Days'
#  'Website Opt In' 'Welcome Series ESI 3.0' 'XML' 'YourSoberPal'
#  '[EG]  Subscribers  |  Engaged  |  Customers  |  Subscription  |  Active  (Loose - 150 Day Opens)'
#  "[SW] Women's 30 Day Engaged - SMS" 'abandoned_cart'
#  'active on site last two days' 'active_campaign' 'affiliate' 'attentive'
#  'avantlink' 'bing' 'bluecore' 'braze' 'broadcast' 'campaign' 'catch'
#  'chirp' 'cordial' 'criteo' 'current' 'daily klaviyo' 'daily-klaviyo'
#  'dailycampaign-text' 'dailycampaign-text ' 'dailycampaign-text  '
#  'dailycampaign-text  utm_source=dailycampaign-text  '
#  'dailycampaign-text-' 'drip' 'email' 'facebad' 'facebook'
#  'facebook-SiteLink-188-0' 'facebook-SiteLink-190-1'
#  'facebook-SiteLink-680-0' 'facebook-SiteLink-683-0'
#  'facebook-SiteLink-683-2' 'facebook-SiteLink-683-4'
#  'facebook-SiteLink-688-1' 'facebook-SiteLink-688-2' 'facebook-fb'
#  'facebook-ig' 'facebook-instagram' 'facebook.com' 'facebook_instagram'
#  'facebook_prospecting' 'facebookads' 'fb' 'fb_ig' 'fbasc' 'fbig' 'fbn'
#  'flow' 'flow-klaviyo' 'flow-text' 'flow-text  ' 'google' 'homepage'
#  'hoobe' 'hs_email' 'ig' 'influencer' 'instagram' 'junip'
#  'khangfujobi2newvid' 'klarna' 'klaviyo' 'leaddyno' 'linkinbio'
#  'linkshare' 'listrak' 'loyalty' 'makarov_fb' 'meta' 'narrativ'
#  'native-app' 'navigation' 'newsletter (all)' 'omnisend' 'organic' 'paid'
#  'paid.social' 'paid_social' 'paidsocial' 'pepperjam' 'pinterest' 'pj'
#  'postscript' 'powereditor' 'preflect' 'refersion' 'seguno' 'sfmc'
#  'shop_app' 'shopify_email' 'smile_rewards' 'snappic' 'social' 'ssw'
#  'thingtesting.com' 'tiktok' 'tiktokad' 'twitter' 'wunderkind' 'yotpo'
#  'youtube' 'zaius']

# %%
channel = pd.DataFrame()
channel['source_channel'] = df['source_channel'].unique()
channel.to_csv('channel.csv')

# %%
# Define mappings of patterns to replacement values
mapping = {
    'fb|facebook|meta|facbook|facebad': 'Facebook(PS)',
    'ig|instagram': 'Instagram(Other)',
    'bing': 'Bing(PSH)',
    'klaviyo': 'Klaviyo(E)',
    'attentive': 'Attentive(T)',
    # main channels
    'paid|pinterest|youtube|tiktok': 'Paid Social',
    'dailycampaign|text|flow': 'Text',
    'orderlyemail|yotpo|mail|newsletter': 'Email',
    'hoobe|organic|navigation|linkinbio': 'Organic & Social',
    'google|microsoft': 'Paid Search',
    'homepage': 'Display',
    'affluencer|affiliate': 'Affiliate',
    'BeefeylFzbvyf|bethany|ciolota|chris|chrome|google_shopping|klarna|loyalty|narrativ|octoly|refer|shop_app|thingtesting.com|trustpilot|color wow|direct|excluded|tbbtyf|non-attributed|baavyvbgf': 'Other'
}

# Use regex to match patterns and replace values in 'main_channel' column
for pattern, replacement in mapping.items():
    df.loc[df['source_channel'].str.contains(pattern, case=False), 'source_channel'] = replacement
df.loc[df['source_channel'] == 'social', 'source_channel'] = 'Organic & Social'

# %%
category = ['Unkown','Facebook(PS)','Instagram(Other)','Bing(PSH)','Klaviyo(E)','Attentive(T)','Paid Social','Text','Email','Organic & Social','Paid Search','Display','Affiliate']
df.loc[~df['source_channel'].isin(category), 'source_channel'] = 'Other'

# %%
print(df['source_channel'].value_counts(normalize=True).head(10) * 100)
print(df['source_channel'].unique())
# Out:
# source_channel
# Unkown              41.685278
# Facebook(PS)        26.410078
# Klaviyo(E)          14.335980
# Instagram(Other)     5.968497
# Text                 3.725480
# Paid Social          3.076716
# Attentive(T)         2.305940
# Bing(PSH)            0.762257
# Affiliate            0.554745
# Organic & Social     0.539775
# Name: proportion, dtype: float64
# ['Unkown' 'Klaviyo(E)' 'Facebook(PS)' 'Text' 'Instagram(Other)'
#  'Paid Social' 'Organic & Social' 'Affiliate' 'Display' 'Attentive(T)'
#  'Bing(PSH)' 'Email' 'Other' 'Paid Search']

# %%
######## filter out wholesale orders

# wholesale = df[['email', 'order_number', 'created_at', 'interval']]
# wholesale = wholesale[~pd.isna(wholesale['interval'])]
# wholesale = wholesale.drop_duplicates()
# wholesale.head()

# %%
# wholesale[wholesale['email'] == 'carlal@plano.gov']

# %%
# print(df.shape)
# print(wholesale.shape)

# %%
# wholesale = wholesale.sort_values(by=['email', 'created_at'])
# wholesale_ids = wholesale.groupby('email').filter(lambda x: (x['interval'] == 0).any())
# wholesale_ids

# %%
# from tqdm import tqdm

# # Define a function to filter groups
# def filter_group(group):
#     # Your filtering logic here
#     return group if (group['interval'] == 0).any() else None

# # Create an empty list to store filtered DataFrames
# filtered_dfs = []

# # Get unique groups
# groups = wholesale.groupby('email')

# # Create a tqdm progress bar
# with tqdm(total=len(groups)) as pbar:
#     # Iterate over groups and filter them
#     for name, group in groups:
#         filtered_df = filter_group(group)
#         if filtered_df is not None:
#             filtered_dfs.append(filtered_df)
#         pbar.update(1)

# # Concatenate the filtered DataFrames
# wholesale_ids = pd.concat(filtered_dfs)

# %%
# wholesale_id = wholesale_ids['email'].unique()
# print(wholesale.shape)
# nonwholesale = wholesale[~wholesale['email'].isin(wholesale_id)]
# print(nonwholesale.shape)
# print(nonwholesale['email'].nunique())

# %%
# filtered_customer_ids = df.groupby('customer_id').filter(lambda x: (x['interval'] <= 1).sum() >= 2)

# %%
df.head()
# Out:
#         order_number                created_at shipping_address_province_code  \
# 658576       1618165 2023-08-09 20:05:18+00:00                             MA
# 281130       1447811 2023-04-15 17:21:29+00:00                             FL
# 613259       1447811 2023-04-15 17:21:29+00:00                             FL
# 101295       1852531 2023-12-18 22:42:37+00:00                             TX
# 552217       1852531 2023-12-18 22:42:37+00:00                             TX
#
#                               email source_channel     sku  \
# 658576    +1508596smbak55@gmail.com         Unkown   CW548
# 281130   0-orange-braces@icloud.com     Klaviyo(E)   CW510
# 613259   0-orange-braces@icloud.com     Klaviyo(E)   CW528
# 101295  0.aliases.iambic@icloud.com   Facebook(PS)   CW528
# 552217  0.aliases.iambic@icloud.com   Facebook(PS)  CWB103
#
#                                                     title  quantity  revenue  \
# 658576             Dream Filter For Picture-Perfect Color         1     24.0
# 281130                             Color Security Shampoo         1     24.0
# 613259   Style on Steroids ~ Color-Safe Texturizing Spray         1     26.0
# 101295   Style on Steroids ~ Color-Safe Texturizing Spray         1     26.0
# 552217  Extra Mist-ical Shine Spray + FREE* Puffer Bag...         1     29.0
#
#          net  interval
# 658576  24.0       NaN
# 281130  24.0       NaN
# 613259  26.0       NaN
# 101295  26.0       NaN
# 552217  29.0       NaN

# %%
df.isna().sum()
# Out:
# order_number                            0
# created_at                              0
# shipping_address_province_code          0
# email                                   0
# source_channel                          0
# sku                                     0
# title                                   0
# quantity                                0
# revenue                                 0
# net                                     0
# interval                          1176670
# dtype: int64

# %%
df.dtypes
# Out:
# order_number                                    Int64
# created_at                        datetime64[us, UTC]
# shipping_address_province_code                 object
# email                                          object
# source_channel                                 object
# sku                                            object
# title                                          object
# quantity                                        Int64
# revenue                                       float64
# net                                           float64
# interval                                      float64
# dtype: object

# %%
df.shape
# Out:
# (940368, 11)
